# %%
df = pd.read_excel("C:/Users/saiko/OneDrive/Desktop/699/Task-3/Car Following model individual Values/CollisionMinGap/collisionMinGapFactor_Metrics.xlsx",header=1)

# %% [markdown]
# # Collisions_min_gap

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df
# Out:
#    Value  rate_of_collisions_time  rate_of_collisions_inserted  Collsions  \
# 0   0.25                    0.000                     0.000000          0
# 1   0.50                    0.000                     0.000000          0
# 2   0.75                    0.000                     0.000000          0
# 3   1.00                    0.000                     0.000000          0
# 4   1.25                    0.258                     0.051683        129
# 5   1.50                    0.654                     0.131010        327
# 6   1.75                    0.872                     0.174679        436
# 7   2.00                    1.006                     0.201522        503
# 8   2.25                    1.006                     0.201522        503
# 9   2.50                    1.504                     0.301282        752
#
#    emergencyBraking  emergencyStops  loaded  inserted  running  \
# 0                 0               0    2496       525       40
# 1                 0               0    2496       525       40
# 2                 0               0    2496       525       40
# 3                 0               0    2496       525       40
# 4                 0               1    2496       765       40
# 5                 0               2    2496       897       40
# 6                 0               0    2496       863       40
# 7                 1               4    2496       939       40
# 8                 1               4    2496       939       40
# 9                 0               1    2496      1283       39
#
#    Collision_Count  Junction_Count
# 0                0             0.0
# 1                0             0.0
# 2                0             0.0
# 3                0             0.0
# 4              129             NaN
# 5              327             NaN
# 6              424            12.0
# 7              503             NaN
# 8              503             NaN
# 9              750             2.0

# %%
# Create subplots
fig, axs = plt.subplots(3, 2, figsize=(12, 8))

# Plot Collision vs Value
axs[0, 0].plot(df['Value'], df['Collision_Count'], marker='o', linestyle='-')
axs[0, 0].set_title('Collision vs Value')
axs[0, 0].set_xlabel('Value')
axs[0, 0].set_ylabel('Collision_Count')

# Plot rate_of_collisions_time vs Value
axs[0, 1].plot(df['Value'], df['rate_of_collisions_inserted'], marker='o', linestyle='-')
axs[0, 1].set_title('rate_of_collisions_inserted vs Value')
axs[0, 1].set_xlabel('Value')
axs[0, 1].set_ylabel('rate_of_collisions_inserted')

# Plot emergencyBraking vs Value
axs[1, 0].plot(df['Value'], df['emergencyBraking'], marker='o', linestyle='-')
axs[1, 0].set_title('emergencyBraking vs Value')
axs[1, 0].set_xlabel('Value')
axs[1, 0].set_ylabel('emergencyBraking')

# Plot emergencyStops vs Value
axs[1, 1].plot(df['Value'], df['emergencyStops'], marker='o', linestyle='-')
axs[1, 1].set_title('emergencyStops vs Value')
axs[1, 1].set_xlabel('Value')
axs[1, 1].set_ylabel('emergencyStops')

# Bar plot for Collision and Junction Collisions vs Value
width = 0.35
x = np.arange(len(df['Value']))
axs[2, 0].bar(x - width/2, df['Collision_Count'], width, label='Collision_Count')
axs[2, 0].bar(x + width/2, df['Junction_Count'].fillna(0), width, label='Junction_Count')
axs[2, 0].set_title('Collision and Junction Collisions vs Value')
axs[2, 0].set_xlabel('Value')
axs[2, 0].set_ylabel('Counts')
axs[2, 0].set_xticks(x)
axs[2, 0].set_xticklabels(df['Value'])
axs[2, 0].legend()

# Remove any empty subplot
fig.delaxes(axs[2, 1])

# Adjust spacing
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# # sigmaerror

# %%
df = pd.read_excel("C:/Users/saiko/OneDrive/Desktop/699/Task-3/Car Following model individual Values/sigmaerror/sigmaerror_stats.xlsx",header=0)

# %%
df
# Out:
#    Value  rate_of_collisions_time  rate_of_collisions_inserted  Collsions  \
# 0    0.1                    0.000                     0.000000          0
# 1    0.2                    0.000                     0.000000          0
# 2    0.3                    0.000                     0.000000          0
# 3    0.4                    0.000                     0.000000          0
# 4    0.5                    0.000                     0.000000          0
# 5    0.6                    0.006                     0.001202          3
# 6    0.7                    0.002                     0.000401          1
# 7    0.8                    0.004                     0.000801          2
# 8    0.9                    0.010                     0.002003          5
# 9    1.0                    0.002                     0.000401          1
#
#    emergencyBraking  emergencyStops  loaded  inserted  running  \
# 0                 0               0    2496       522       40
# 1                 0               0    2496       336       40
# 2                 0               0    2496       103       40
# 3                 0               0    2496        78       40
# 4                 1               0    2496        71       40
# 5                 0               0    2496        59       40
# 6                 2               0    2496        55       40
# 7                 1               0    2496        58       40
# 8                 0               1    2496        62       40
# 9                 2               0    2496        49       40
#
#    Collision_Count  Junction_Count
# 0                0             0.0
# 1                0             0.0
# 2                0             0.0
# 3                0             0.0
# 4                0             0.0
# 5                3             NaN
# 6                1             NaN
# 7                2             NaN
# 8                4             1.0
# 9                1             NaN

# %%
# Create subplots
fig, axs = plt.subplots(3, 2, figsize=(12, 8))

# Plot Collision vs Value
axs[0, 0].plot(df['Value'], df['Collision_Count'], marker='o', linestyle='-')
axs[0, 0].set_title('Collision vs Value')
axs[0, 0].set_xlabel('Value')
axs[0, 0].set_ylabel('Collision_Count')

# Plot rate_of_collisions_time vs Value
axs[0, 1].plot(df['Value'], df['rate_of_collisions_inserted'], marker='o', linestyle='-')
axs[0, 1].set_title('rate_of_collisions_inserted vs Value')
axs[0, 1].set_xlabel('Value')
axs[0, 1].set_ylabel('rate_of_collisions_inserted')

# Plot emergencyBraking vs Value
axs[1, 0].plot(df['Value'], df['emergencyBraking'], marker='o', linestyle='-')
axs[1, 0].set_title('emergencyBraking vs Value')
axs[1, 0].set_xlabel('Value')
axs[1, 0].set_ylabel('emergencyBraking')

# Plot emergencyStops vs Value
axs[1, 1].plot(df['Value'], df['emergencyStops'], marker='o', linestyle='-')
axs[1, 1].set_title('emergencyStops vs Value')
axs[1, 1].set_xlabel('Value')
axs[1, 1].set_ylabel('emergencyStops')
# Bar plot for Collision and Junction Collisions vs Value
width = 0.35
x = np.arange(len(df['Value']))
axs[2, 0].bar(x - width/2, df['Collision_Count'], width, label='Collision_Count')
axs[2, 0].bar(x + width/2, df['Junction_Count'].fillna(0), width, label='Junction_Count')
axs[2, 0].set_title('Collision and Junction Collisions vs Value')
axs[2, 0].set_xlabel('Value')
axs[2, 0].set_ylabel('Counts')
axs[2, 0].set_xticks(x)
axs[2, 0].set_xticklabels(df['Value'])
axs[2, 0].legend()

# Remove any empty subplot
fig.delaxes(axs[2, 1])

# Adjust spacing
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# # Tau

# %%
df = pd.read_excel("C:/Users/saiko/OneDrive/Desktop/699/Task-3/Car Following model individual Values/Tau/Tau_Metrics.xlsx",header=0)

# %%
df['Junction_Count'] = df['Unnamed: 10']

# %%
df
# Out:
#    Value  rate_of_collisions_time  rate_of_collisions_inserted  Collsions  \
# 0   0.01                    0.092                     0.018429         46
# 1   0.02                    0.050                     0.010016         25
# 2   0.03                    0.042                     0.008413         21
# 3   0.04                    0.054                     0.010817         27
# 4   0.05                    0.036                     0.007212         18
# 5   0.06                    0.036                     0.007212         18
# 6   0.07                    0.032                     0.006410         16
# 7   0.08                    0.012                     0.002404          6
# 8   0.09                    0.014                     0.002804          7
# 9   0.10                    0.022                     0.004407         11
#
#    emergencyBraking  emergencyStops  loaded  inserted  running  \
# 0                26               2    2496       677       40
# 1                22               3    2496       615       40
# 2                 9               0    2496       606       40
# 3                25               2    2496       622       40
# 4                10               2    2496       589       40
# 5                12               0    2496       579       40
# 6                 9               1    2496       571       40
# 7                 4               0    2496       556       40
# 8                 3               0    2496       565       40
# 9                 3               0    2496       576       40
#
#    Collision_Count  Unnamed: 10  Junction_Count
# 0               46          NaN             NaN
# 1               25          NaN             NaN
# 2               21          NaN             NaN
# 3               27          NaN             NaN
# 4               18          NaN             NaN
# 5               18          NaN             NaN
# 6               15          1.0             1.0
# 7                6          NaN             NaN
# 8                7          NaN             NaN
# 9               11          NaN             NaN

# %%
# Create subplots
fig, axs = plt.subplots(3, 2, figsize=(12, 8))

# Plot Collision vs Value
axs[0, 0].plot(df['Value'], df['Collision_Count'], marker='o', linestyle='-')
axs[0, 0].set_title('Collision vs Value')
axs[0, 0].set_xlabel('Value')
axs[0, 0].set_ylabel('Collision_Count')

# Plot rate_of_collisions_time vs Value
axs[0, 1].plot(df['Value'], df['rate_of_collisions_time'], marker='o', linestyle='-')
axs[0, 1].set_title('rate_of_collisions_time vs Value')
axs[0, 1].set_xlabel('Value')
axs[0, 1].set_ylabel('rate_of_collisions_time')

# Plot emergencyBraking vs Value
axs[1, 0].plot(df['Value'], df['emergencyBraking'], marker='o', linestyle='-')
axs[1, 0].set_title('emergencyBraking vs Value')
axs[1, 0].set_xlabel('Value')
axs[1, 0].set_ylabel('emergencyBraking')

# Plot emergencyStops vs Value
axs[1, 1].plot(df['Value'], df['emergencyStops'], marker='o', linestyle='-')
axs[1, 1].set_title('emergencyStops vs Value')
axs[1, 1].set_xlabel('Value')
axs[1, 1].set_ylabel('emergencyStops')

# Bar plot for Collision and Junction Collisions vs Value
width = 0.35
x = np.arange(len(df['Value']))
axs[2, 0].bar(x - width/2, df['Collision_Count'], width, label='Collision_Count')
axs[2, 0].bar(x + width/2, df['Junction_Count'].fillna(0), width, label='Junction_Count')
axs[2, 0].set_title('Collision and Junction Collisions vs Value')
axs[2, 0].set_xlabel('Value')
axs[2, 0].set_ylabel('Counts')
axs[2, 0].set_xticks(x)
axs[2, 0].set_xticklabels(df['Value'])
axs[2, 0].legend()
# Remove any empty subplot
fig.delaxes(axs[2, 1])

# Adjust spacing
plt.tight_layout()

# Show the plot
plt.show()
