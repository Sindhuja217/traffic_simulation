# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_excel("C:/Users/saiko/OneDrive/Desktop/699/Task-3/Junction_collisions/jmIgnoreJunctionFoeProb_collisions.xlsx",header=0)

# %%
df['Junction_Count'] = df['Unnamed: 10']

# %%
df
# Out:
#    Value  rate_of_collisions_time  rate_of_collisions_inserted  Collsions  \
# 0    0.1                    0.024                     0.004808         12
# 1    0.2                    0.082                     0.016426         41
# 2    0.3                    0.090                     0.018029         45
# 3    0.4                    0.082                     0.016426         41
# 4    0.5                    0.048                     0.009615         24
# 5    0.6                    0.052                     0.010417         26
# 6    0.7                    0.094                     0.018830         47
# 7    0.8                    0.100                     0.020032         50
# 8    0.9                    0.106                     0.021234         53
# 9    1.0                    0.030                     0.006010         15
#
#    emergencyBraking  emergencyStops  loaded  inserted  running  \
# 0                13               0    2496       582       40
# 1                16               0    2496       681       40
# 2                18               0    2496       682       40
# 3                26               2    2496       664       40
# 4                16               2    2496       614       40
# 5                17               2    2496       618       40
# 6                24               2    2496       682       40
# 7                30               3    2496       693       40
# 8                24               1    2496       704       40
# 9                10               0    2496       599       40
#
#    Collision_Count  Unnamed: 10  Junction_Count
# 0               12          NaN             NaN
# 1               41          NaN             NaN
# 2               45          NaN             NaN
# 3               41          NaN             NaN
# 4               24          NaN             NaN
# 5               24          2.0             2.0
# 6               47          NaN             NaN
# 7               50          NaN             NaN
# 8               53          NaN             NaN
# 9               15          NaN             NaN

# %%
# Create subplots
fig, axs = plt.subplots(3, 2, figsize=(12, 8))

# Plot Collision vs Value
axs[0, 0].plot(df['Value'], df['Collision_Count'], marker='o', linestyle='-')
axs[0, 0].set_title('Collision vs Value')
axs[0, 0].set_xlabel('Value')
axs[0, 0].set_ylabel('Collision_Count')
axs[0, 0].axhline(y=46, color='r', linestyle='--', label='Threshold')

# Plot rate_of_collisions_time vs Value
axs[0, 1].plot(df['Value'], df['rate_of_collisions_inserted'], marker='o', linestyle='-')
axs[0, 1].set_title('rate_of_collisions_inserted vs Value')
axs[0, 1].set_xlabel('Value')
axs[0, 1].set_ylabel('rate_of_collisions_inserted')
axs[0, 1].axhline(y=0.018, color='r', linestyle='--', label='Threshold')

# Plot emergencyBraking vs Value
axs[1, 0].plot(df['Value'], df['emergencyBraking'], marker='o', linestyle='-')
axs[1, 0].set_title('emergencyBraking vs Value')
axs[1, 0].set_xlabel('Value')
axs[1, 0].set_ylabel('emergencyBraking')
axs[1, 0].axhline(y=26, color='r', linestyle='--', label='Threshold')

# Plot emergencyStops vs Value
axs[1, 1].plot(df['Value'], df['emergencyStops'], marker='o', linestyle='-')
axs[1, 1].set_title('emergencyStops vs Value')
axs[1, 1].set_xlabel('Value')
axs[1, 1].set_ylabel('emergencyStops')
axs[1, 1].axhline(y=2, color='r', linestyle='--', label='Threshold')

# Bar plot for Collision and Junction Collisions vs Value
width = 0.35
x = np.arange(len(df['Value']))
axs[2, 0].bar(x - width/2, df['Collision_Count'], width, label='Collision_Count')
axs[2, 0].bar(x + width/2, df['Junction_Count'].fillna(0), width, label='Junction_Count')
axs[2, 0].set_title('Collision and Junction Collisions vs Value')
axs[2, 0].set_xlabel('Value')
axs[2, 0].set_ylabel('Counts')
axs[2, 0].set_xticks(x)
axs[2, 0].set_xticklabels(df['Value'])
axs[2, 0].legend()

# Remove any empty subplot
fig.delaxes(axs[2, 1])

# Adjust spacing
plt.tight_layout()

# Show the plot
plt.show()

# %%
df = pd.read_excel("C:/Users/saiko/OneDrive/Desktop/699/Task-3/Junction_collisions/jmTimegapMinor_collisions.xlsx",header=0)

# %%
df
# Out:
#    Value  rate_of_collisions_time  rate_of_collisions_inserted  Collsions  \
# 0    0.1                    0.048                     0.009615         24
# 1    0.2                    0.056                     0.011218         28
# 2    0.3                    0.056                     0.011218         28
# 3    0.4                    0.056                     0.011218         28
# 4    0.5                    0.086                     0.017228         43
# 5    0.6                    0.086                     0.017228         43
# 6    0.7                    0.092                     0.018429         46
# 7    0.8                    0.092                     0.018429         46
# 8    0.9                    0.092                     0.018429         46
# 9    1.0                    0.092                     0.018429         46
#
#    emergencyBraking  emergencyStops  loaded  inserted  running  \
# 0                19               1    2496       618       40
# 1                18               2    2496       636       40
# 2                18               2    2496       636       40
# 3                18               2    2496       636       40
# 4                31               2    2496       666       40
# 5                31               2    2496       666       40
# 6                26               2    2496       677       40
# 7                26               2    2496       677       40
# 8                26               2    2496       677       40
# 9                26               2    2496       677       40
#
#    Collision_Count  Junction_Count
# 0               23             1.0
# 1               27             1.0
# 2               27             1.0
# 3               27             1.0
# 4               43             NaN
# 5               43             NaN
# 6               46             NaN
# 7               46             NaN
# 8               46             NaN
# 9               46             NaN

# %%
# Create subplots
fig, axs = plt.subplots(3, 2, figsize=(12, 8))

# Plot Collision vs Value
axs[0, 0].plot(df['Value'], df['Collision_Count'], marker='o', linestyle='-')
axs[0, 0].set_title('Collision vs Value')
axs[0, 0].set_xlabel('Value')
axs[0, 0].set_ylabel('Collision_Count')
axs[0, 0].axhline(y=46, color='r', linestyle='--', label='Threshold')

# Plot rate_of_collisions_time vs Value
axs[0, 1].plot(df['Value'], df['rate_of_collisions_inserted'], marker='o', linestyle='-')
axs[0, 1].set_title('rate_of_collisions_inserted vs Value')
axs[0, 1].set_xlabel('Value')
axs[0, 1].set_ylabel('rate_of_collisions_inserted')
axs[0, 1].axhline(y=0.018, color='r', linestyle='--', label='Threshold')

# Plot emergencyBraking vs Value
axs[1, 0].plot(df['Value'], df['emergencyBraking'], marker='o', linestyle='-')
axs[1, 0].set_title('emergencyBraking vs Value')
axs[1, 0].set_xlabel('Value')
axs[1, 0].set_ylabel('emergencyBraking')
axs[1, 0].axhline(y=26, color='r', linestyle='--', label='Threshold')

# Plot emergencyStops vs Value
axs[1, 1].plot(df['Value'], df['emergencyStops'], marker='o', linestyle='-')
axs[1, 1].set_title('emergencyStops vs Value')
axs[1, 1].set_xlabel('Value')
axs[1, 1].set_ylabel('emergencyStops')
axs[1, 1].axhline(y=2, color='r', linestyle='--', label='Threshold')

# Bar plot for Collision and Junction Collisions vs Value
width = 0.35
x = np.arange(len(df['Value']))
axs[2, 0].bar(x - width/2, df['Collision_Count'], width, label='Collision_Count')
axs[2, 0].bar(x + width/2, df['Junction_Count'].fillna(0), width, label='Junction_Count')
axs[2, 0].set_title('Collision and Junction Collisions vs Value')
axs[2, 0].set_xlabel('Value')
axs[2, 0].set_ylabel('Counts')
axs[2, 0].set_xticks(x)
axs[2, 0].set_xticklabels(df['Value'])
axs[2, 0].legend()

# Remove any empty subplot
fig.delaxes(axs[2, 1])

# Adjust spacing
plt.tight_layout()

# Show the plot
plt.show()
